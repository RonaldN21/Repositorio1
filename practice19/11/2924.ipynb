# %% [markdown]
# <a href="https://colab.research.google.com/github/RonaldN21/Repositorio1/blob/master/practice19/11/2924.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Welcome to Colab - class 19/11/2024

# %%
import pandas as pd

# %% [markdown]
# Series and dataframe

# %%
series=pd.Series(data=[1,2,3,4,5], index=['Ronald','Silvana','Tifani','Evelyn','Fernanda'])

# %%
print(series)
# Out:
# Ronald      1
# Silvana     2
# Tifani      3
# Evelyn      4
# Fernanda    5
# dtype: int64

# %%
print(series.index)
# Out:
# Index(['Ronald', 'Silvana', 'Tifani', 'Evelyn', 'Fernanda'], dtype='object')

# %%
'Silvana' in series
# Out:
# True

# %%
series*2
# Out:
# Ronald       2
# Silvana      4
# Tifani       6
# Evelyn       8
# Fernanda    10
# dtype: int64

# %%
print(series)
# Out:
# Ronald      1
# Silvana     2
# Tifani      3
# Evelyn      4
# Fernanda    5
# dtype: int64

# %%
series=series*2
print(series)
# Out:
# Ronald       4
# Silvana      8
# Tifani      12
# Evelyn      16
# Fernanda    20
# dtype: int64

# %%
series[[1,3]]
# Out:
# <ipython-input-15-ce78a48b16cf>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   series[[1,3]]
# Silvana     8
# Evelyn     16
# dtype: int64

# %%
# d={'Ronald':1,'Silvana':2,'Tifani':3,'Evelyn':4,'Fernanda':5}
d={'one':pd.Series(data=[100,200,300],index=['apple','ball','clock']),
'two':pd.Series(data=[111,222,333,444],index=['apple','ball','clock','orange'])}
df=pd.DataFrame(d)
# DATAFRAME
print(df)
# Out:
#           one  two
# apple   100.0  111
# ball    200.0  222
# clock   300.0  333
# orange    NaN  444

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
df
# Out:
#           one  two
# apple   100.0  111
# ball    200.0  222
# clock   300.0  333
# orange    NaN  444

# %%
import pandas as pd

# Crea un diccionario con los datos
data = {'Nombre': ['Ana', 'Juan', 'Pedro'],
        'Edad': [25, 30, 35],
        'Ciudad': ['Madrid', 'Barcelona', 'Valencia']}

# Crea el DataFrame
df = pd.DataFrame(data)

# Imprime el DataFrame
print(df)
# Out:
#   Nombre  Edad     Ciudad
# 0    Ana    25     Madrid
# 1   Juan    30  Barcelona
# 2  Pedro    35   Valencia

# %%
data ={
    'name':['Alice','Bob','Charlie','Diana'],
    'Math':[90,80,78,92],
    'Science':[88,92,80,85],
    'English':[75,80,88,90]
}
df=pd.DataFrame(data)
print(df)
# Out:
#       name  Math  Science  English
# 0    Alice    90       88       75
# 1      Bob    80       92       80
# 2  Charlie    78       80       88
# 3    Diana    92       85       90

# %%
df['AI']=df['Science']*df['English']
df
# Out:
#       name  Math  Science  English    AI
# 0    Alice    90       88       75  6600
# 1      Bob    80       92       80  7360
# 2  Charlie    78       80       88  7040
# 3    Diana    92       85       90  7650

# %%
df['AI']=df['Science']/2+df['English']/2
df
# Out:
#       name  Math  Science  English    AI
# 0    Alice    90       88       75  81.5
# 1      Bob    80       92       80  86.0
# 2  Charlie    78       80       88  84.0
# 3    Diana    92       85       90  87.5

# %%
df['Approved in AI']=df['AI']>85
df
# Out:
#       name  Math  Science  English    AI  fiter  Approved  Approved in AI
# 0    Alice    90       88       75  81.5  False     False           False
# 1      Bob    80       92       80  86.0   True      True            True
# 2  Charlie    78       80       88  84.0  False     False           False
# 3    Diana    92       85       90  87.5   True      True            True

# %%
df.drop('',axis=1)
# Out:
#       name  Math  Science  English    AI  Approved  Approved in AI
# 0    Alice    90       88       75  81.5     False           False
# 1      Bob    80       92       80  86.0      True            True
# 2  Charlie    78       80       88  84.0     False           False
# 3    Diana    92       85       90  87.5      True            True

# %%
df.pop('Science')
df
# Out:
#       name  Math  English    AI  Approved  Approved in AI
# 0    Alice    90       75  81.5     False           False
# 1      Bob    80       80  86.0      True            True
# 2  Charlie    78       88  84.0     False           False
# 3    Diana    92       90  87.5      True            True
